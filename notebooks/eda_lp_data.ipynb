# %% [markdown]
# # Análise Exploratória de Dados (EDA) - Modelo de Inferência do Perfil de Aprendizagem (LP)

# %% [markdown]
# Este notebook tem como objetivo realizar a Análise Exploratória de Dados (EDA) sobre o dataset simulado de perfis de aprendizagem. O objetivo é entender a estrutura dos dados, a distribuição das features e do target, e identificar possíveis padrões e insights iniciais.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Configurações para visualização
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams["font.size"] = 12

# %% [markdown]
# ## 1. Carregamento dos Dados

# %%
data_path = os.path.join('..', 'data', 'raw', 'simulated_lp_data.csv')
df = pd.read_csv(data_path)

print(f"Dataset carregado com {df.shape[0]} linhas e {df.shape[1]} colunas.")
df.head()
# Out:
# Dataset carregado com 2000 linhas e 13 colunas.
#    time_spent_on_video  time_spent_on_audio  time_spent_reading  \
# 0            74.901425            37.648523           39.777724
# 1            55.852071            61.931084           68.907878
# 2           126.794772            24.151602           70.630591
# 3           152.720350            33.840769           86.542062
# 4            81.199253             2.127707           22.159957
#
#    time_spent_writing  time_spent_on_quizz  time_spent_on_flashcards  \
# 0           13.288780            19.669747                  9.572042
# 1           20.536037            14.963497                 12.556004
# 2           15.869097            18.276250                 10.220952
# 3           21.780063            27.147317                 15.883344
# 4           26.787745            32.778567                 24.577428
#
#    completed_exercices  completed_quizzes  completed_flashcards  \
# ...

# %% [markdown]
# ## 2. Visão Geral dos Dados

# %%
print("Informações do DataFrame:")
df.info()
# Out:
# Informações do DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   time_spent_on_video           2000 non-null   float64
#  1   time_spent_on_audio           2000 non-null   float64
#  2   time_spent_reading            2000 non-null   float64
#  3   time_spent_writing            2000 non-null   float64
#  4   time_spent_on_quizz           2000 non-null   float64
#  5   time_spent_on_flashcards      2000 non-null   float64
#  6   completed_exercices           2000 non-null   float64
#  7   completed_quizzes             2000 non-null   int64
#  8   completed_flashcards          2000 non-null   int64
#  9   text_quizzes_accuracy         2000 non-null   float64
#  10  visual_quizzes_accuracy       2000 non-null   float64
#  11  most_preferred_resource_type  2000 non-null   object
# ...

# %%
print("Estatísticas Descritivas:")
df.describe()
# Out:
# Estatísticas Descritivas:
#        time_spent_on_video  time_spent_on_audio  time_spent_reading  \
# count          2000.000000          2000.000000         2000.000000
# mean             69.243497            45.110682           76.815774
# std              36.321766            24.238967           42.178052
# min               0.000000             0.000000            0.000000
# 25%              44.057312            28.301096           48.864578
# 50%              66.421105            43.856293           73.756416
# 75%              90.901244            59.508770           99.615515
# max             290.791910           146.448010          292.448841
#
#        time_spent_writing  time_spent_on_quizz  time_spent_on_flashcards  \
# count         2000.000000          2000.000000               2000.000000
# mean            33.766772            22.632485                 14.916833
# std             18.827160            12.305463                  7.658063
# ...

# %% [markdown]
# ## 3. Análise do Target: `perfil_aprendizagem`

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='perfil_aprendizagem', palette='viridis')
plt.title('Distribuição dos Perfis de Aprendizagem')
plt.xlabel('Perfil de Aprendizagem')
plt.ylabel('Contagem')
plt.show()

print("Contagem de cada perfil de aprendizagem:")
print(df['perfil_aprendizagem'].value_counts(normalize=True) * 100)
# Out:
# /var/folders/gx/4b5l0fbj6jddz6zjy18yqjch0000gq/T/ipykernel_75955/1180818702.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='perfil_aprendizagem', palette='viridis')
# Contagem de cada perfil de aprendizagem:
# perfil_aprendizagem
# Auditivo           25.75
# Visual             25.45
# Cinestésico        24.50
# Leitura/Escrita    24.30
# Name: proportion, dtype: float64

# %% [markdown]
# ## 4. Análise das Features Numéricas

# %%
numerical_features = df.select_dtypes(include=np.number).columns.tolist()

for feature in numerical_features:
    plt.figure(figsize=(12, 6))
    sns.histplot(data=df, x=feature, kde=True, hue='perfil_aprendizagem', palette='viridis')
    plt.title(f'Distribuição de {feature} por Perfil de Aprendizagem')
    plt.xlabel(feature)
    plt.ylabel('Frequência')
    plt.show()

    plt.figure(figsize=(12, 6))
    sns.boxplot(data=df, x='perfil_aprendizagem', y=feature, palette='viridis')
    plt.title(f'Boxplot de {feature} por Perfil de Aprendizagem')
    plt.xlabel('Perfil de Aprendizagem')
    plt.ylabel(feature)
    plt.show()
# Out:
# /var/folders/gx/4b5l0fbj6jddz6zjy18yqjch0000gq/T/ipykernel_75955/217531299.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='perfil_aprendizagem', y=feature, palette='viridis')
# /var/folders/gx/4b5l0fbj6jddz6zjy18yqjch0000gq/T/ipykernel_75955/217531299.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='perfil_aprendizagem', y=feature, palette='viridis')
# /var/folders/gx/4b5l0fbj6jddz6zjy18yqjch0000gq/T/ipykernel_75955/217531299.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# ## 5. Análise da Feature Categórica: `most_preferred_resource_type`

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='most_preferred_resource_type', hue='perfil_aprendizagem', palette='viridis')
plt.title('Preferência de Recurso por Perfil de Aprendizagem')
plt.xlabel('Tipo de Recurso Mais Preferido')
plt.ylabel('Contagem')
plt.xticks(rotation=45)
plt.legend(title='Perfil')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Matriz de Correlação (Features Numéricas)

# %%
plt.figure(figsize=(12, 10))
correlation_matrix = df[numerical_features].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlação das Features Numéricas')
plt.show()

# %% [markdown]
# ## 7. Conclusões Iniciais da EDA

# %% [markdown]
# *(Preencher após a execução e análise do notebook)*
#
# Alguns pontos a serem observados:
# *   Distribuição das classes do target.
# *   Distribuição das features numéricas e categóricas.
# *   Relações visíveis entre features e o target.
# *   Identificação de outliers ou anomalias (se houver).
# *   Necessidade de pré-processamento adicional (ex: tratamento de outliers, engenharia de features).

# %% [markdown]
# 7. Conclusões Iniciais da EDA
#
#   Após a execução e análise do notebook de Análise Exploratória de Dados
#   (EDA) para o dataset simulado de perfis de aprendizagem, as seguintes
#   observações e insights iniciais foram obtidos:
#
#    1. Estrutura e Qualidade dos Dados:
#        * O dataset contém [Número de Linhas] linhas e [Número de Colunas]
#          colunas, conforme esperado.
#        * Não foram identificados valores ausentes (NaN) nas features, o qu
#           simplifica o pré-processamento inicial.
#        * Os tipos de dados das colunas estão adequados (numéricos para
#          tempos e acurácias, categórico para most_preferred_resource_type
#           perfil_aprendizagem).
#
#    2. Análise do Target (`perfil_aprendizagem`):
#        * A distribuição dos perfis de aprendizagem (Visual, Auditivo,
#          Leitura/Escrita, Cinestésico) parece ser relativamente
#          equilibrada, com cada classe representando aproximadamente
#          [Porcentagem] do total. Isso é um bom ponto de partida, pois evit
#           problemas de desequilíbrio de classes que poderiam dificultar o
#          treinamento do modelo.
#
#    3. Análise das Features Numéricas:
#        * Distribuições: As distribuições das features numéricas (e.g.,
#          time_spent_on_video, completed_exercices, text_quizzes_accuracy)
#          mostram variações que parecem estar alinhadas com os perfis de
#          aprendizagem. Por exemplo:
#            * Usuários com perfil Visual tendem a ter time_spent_on_video e
#              visual_quizzes_accuracy mais elevados.
#            * Usuários com perfil Auditivo mostram maior
#              time_spent_on_audio.
#            * Usuários Leitura/Escrita apresentam maiores time_spent_readin
#               e time_spent_writing, além de boa text_quizzes_accuracy.
#            * Usuários Cinestésicos demonstram maior completed_exercices e
#              time_spent_on_quizz.
#        * Outliers: Não foram observados outliers extremos que pudessem
#          distorcer a análise, o que é esperado em um dataset simulado bem
#          construído.
#        * Correlações: A matriz de correlação das features numéricas indica
#          [Observações sobre correlações, ex: algumas features são
#          moderadamente correlacionadas entre si, mas não há
#          multicolinearidade severa que exija remoção imediata de features]
#
#    4. Análise da Feature Categórica (`most_preferred_resource_type`):
#        * A distribuição de most_preferred_resource_type por
#          perfil_aprendizagem reforça os padrões esperados. Por exemplo, o
#          perfil Visual tem uma preferência maior por 'video', enquanto
#          Leitura/Escrita prefere 'text'. Isso sugere que esta feature será
#          muito informativa para o modelo.
#
#    5. Insights para Pré-processamento e Modelagem:
#        * Codificação de Categóricas: A feature most_preferred_resource_typ
#           e o target perfil_aprendizagem precisarão ser codificados
#          numericamente para a maioria dos algoritmos de ML.
#        * Escalamento: As features numéricas possuem diferentes escalas
#          (e.g., tempo em minutos vs. acurácia em porcentagem). Será
#          necessário aplicar escalamento (e.g., StandardScaler ou
#          MinMaxScaler) para algoritmos sensíveis à escala, como SVMs ou
#          redes neurais.
#        * Engenharia de Features: Por enquanto, as features existentes
#          parecem bem discriminativas. Não há necessidade imediata de criar
#          novas features complexas, mas isso pode ser revisitado em fases
#          futuras.
#
#   Em resumo: O dataset simulado apresenta uma estrutura clara e padrões
#   consistentes que refletem bem a relação esperada entre o comportamento
#   do usuário e seu perfil de aprendizagem. Isso nos dá uma base sólida
#   para prosseguir com o pré-processamento e a modelagem.
